# %% [markdown]
# ## HTML 기본구조
# ```html
# <!DOCTYPE html>
# <html lang="ko">
#     <head>
#         <meta charset="UTF-8">
#         <title>문서 제목</title>
#     </head>
#     <body>
#         <hi>제목</hi>
#         <p>내용 주저리 주저리</p>
#     </body>
# </html>
# ```
#
# ## 제목
# - 코드
#
# ```html
# <h1>h1 제목입니다.</h1>
# <h2>h2 제목입니다.</h2>
# <h3>h3 제목입니다.</h3>
# <h4>h4 제목입니다.</h4>
# <h5>h5 제목입니다.</h5>
# <h6>h6 제목입니다.</h6>
# ```
#
# - 결과
#
# -----
# <h1>h1 제목입니다.</h1>
# <h2>h2 제목입니다.</h2>
# <h3>h3 제목입니다.</h3>
# <h4>h4 제목입니다.</h4>
# <h5>h5 제목입니다.</h5>
# <h6>h6 제목입니다.</h6>
#
# -----
#
# ## 내용
# - 코드
#
# ```html
# <p>이 밑에 빈 공간이 있습니다.</p>
# <p>이 위에 빈 공간이 있습니다.</p
# <p><b>굵게 표시됩니다.</b></p>
# <p>
# <i>기울임꼴로 표시됩니다.</i</p>><p>
# <strong>강하게 강조합니다.</stron</p>g<p>>
# <em>약하게 강조합니다.</</p>
# <p><ins>밑줄이 표시됩니다.</ins></p>
# <p>
# <del>취소선이 표시됩니다.</del</p>
# <p>이 문장의<sup>윗첨자</sup></p>
# <p>이 문장의H<sub아래첨자2</sub</p>
# <p><small>작은 글씨</small></p>
# <p>이 밑에 가로줄이 있습니다.</p>
# <hr><p>
# 이 위에 가로줄이 있습니</p>다.b>
#
# - m>>
# ```
#
# -<p>이 밑에 빈 공간이 있습니다.</p>
# <p>이 위에 빈 공간이 있습니다.</p>
# <p><b>굵게 표시됩니다.</b></p>
# <p><i>기울임꼴로 표시됩니다.</i></p>
# <p><strong>강하게 강조합니다.</strong></p>
# <p><em>약하게 강조합니다.</em></p>
# <p><ins>밑줄이 표시됩니다.</ins></p>
# <p><del>취소선이 표시됩니다.</del></p>
# <p>이 문장의<sup>윗첨자</sup></p>
# <p>이 문장의<sub>아래첨자</sub></p>
# <p><small>작은 글씨</small></p>
# <p>이 밑에 가로줄이 있습니다.</p>
# <hr>
# <p>이 위에 가로줄이 있습니다.</p>제목입니다.</h6>
#
# -----
#
# ## 목록
# ## 표
# ## 이미지
# ## 오디오 / 비디오
# ## 하이퍼링크
# ## 폼
